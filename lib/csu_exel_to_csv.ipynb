# %%
import pandas as pd

# Replace 'path/to/your/excel/file.xlsx' with the actual path to your Excel file
excel_file = pd.ExcelFile('../csu-codes/all-codes.xlsx')

# Get the sheet names
for code in excel_file.sheet_names:
    df = pd.read_excel(excel_file, sheet_name=code)
    print(df["Name"][0])

# Print the sheet names
# Out:
# 0    CS164
# Name: Name, dtype: object
# 0    CS462
# Name: Name, dtype: object
# 0    CS164
# Name: Name, dtype: object
# 0    CS162
# 1    CS455
# Name: Name, dtype: object
# 0    CS470 - Modules
# Name: Name, dtype: object
# 0    CS356
# Name: Name, dtype: object
# 0              CS270
# 1              CS453
# 2    CS470 - Modules
# Name: Name, dtype: object
# 0    CS214
# 1    CS314
# Name: Name, dtype: object
# 0    CS425
# Name: Name, dtype: object
# 0    CS152
# 1    CS164
# 2    CS165
# Name: Name, dtype: object
# 0    CS455
# Name: Name, dtype: object
# 0    CS455
# Name: Name, dtype: object
# 0    CS220
# 1    CS345
# Name: Name, dtype: object
# 0    CS440
# Name: Name, dtype: object
# 0    CS470 - Modules
# Name: Name, dtype: object
# 0    CS462
# Name: Name, dtype: object
# 0    CS456
# Name: Name, dtype: object
# 0    CS430
# Name: Name, dtype: object
# 0    CS440
# Name: Name, dtype: object
# 0    CS414
# Name: Name, dtype: object
# 0    CS455
# ...
